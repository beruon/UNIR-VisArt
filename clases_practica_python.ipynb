# %% [markdown]
# # Ejecución comentada del algoritmo
#
# ## Librerías necesarias
#
# Cargamos todas las librerías que necesitaremos para resolver la actividad.
#
# * numpy: Trabajo con arrays
# * matplotlib: Representación de funciones e imágenes
# * opencv: Carga de imágenes y obtención de propiedades y canales de la misma
# * scipy: Librería para operaciones matemáticas
# * operator: Librería para trabajar con sus operadores

# %% [markdown]
# Instalo la libraría CV2
# https://stackoverflow.com/questions/38109270/cv2-import-error-on-jupyter-notebook

# %%
# !pip3 install opencv-python

# %%
# Importamos librerias necesarias 
import numpy as np
import matplotlib.pyplot as plt
import cv2
from scipy.signal import argrelextrema
import operator

# %%
img = cv2.imread("imagenes/palacio-real.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %% [markdown]
# # Sobel Operator

# %%
# set the kernel size, depending on whether we are using the Sobel
# filter or the Scharr operator, then compute the gradients along
# the x and y axis, respectively
#ksize = -1 # "scharr"
ksize = 3  #  Sobel
gX = cv2.Sobel(gray, ddepth=cv2.CV_32F, dx=1, dy=0, ksize=ksize)
gY = cv2.Sobel(gray, ddepth=cv2.CV_32F, dx=0, dy=1, ksize=ksize)
# the gradient magnitude images are now of the floating point data
# type, so we need to take care to convert them back a to unsigned
# 8-bit integer representation so other OpenCV functions can operate
# on them and visualize them
gX = cv2.convertScaleAbs(gX)
gY = cv2.convertScaleAbs(gY)
# combine the gradient representations into a single image
combined = cv2.addWeighted(gX, 0.5, gY, 0.5, 0)

# %%
# show our output images
cv2.imshow("Sobel/Scharr X", gX)
cv2.imshow("Sobel/Scharr Y", gY)
cv2.imshow("Sobel/Scharr Combined", combined)
cv2.waitKey(0)
# Out:
# -1

# %%
img = cv2.imread("imagenes/1004.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
def imshow(img):

  fig,ax = plt.subplots(figsize=(5,5))

  ax.imshow(img,cmap=plt.cm.gray)

  ax.set_xticks([])

  ax.set_yticks([])

  plt.show()

# %%
hist = cv2.calcHist([gray], [0], None, [256], [0, 256])
plt.plot(hist, color='gray' )

plt.xlabel('intensidad de iluminacion')
plt.ylabel('cantidad de pixeles')
plt.show()
# https://acodigo.blogspot.com/2017/08/histogramas-opencv-python.html

# %% [markdown]
# Para aclarar la imagen (mucho contraste) voy a emplear la suma
# https://programacionpython80889555.wordpress.com/2020/11/26/operaciones-aritmeticas-sobre-imagenes-con-python-y-opencv-1a-parte/
# https://programacionpython80889555.wordpress.com/2023/10/30/ajuste-de-brillo-y-contraste-en-imagenes-con-opencv-y-python/

# %%
suma = cv2.add(gray,gray)
suma2 = cv2.add(gray,suma)
suma3 = cv2.add(gray,suma2)
suma4 = cv2.add(gray,suma3)
suma5 = cv2.add(gray,suma4)
suma10= cv2.add(suma5,suma5)
suma20= cv2.add(suma10,suma10)
suma40= cv2.add(suma20,suma20)

# %%
imshow(suma40)

# %%
producto = cv2.multiply(gray,gray)
producto2 = cv2.multiply(producto,producto)
producto4 = cv2.multiply(producto2,producto2)
producto8 = cv2.multiply(producto4,producto4)
producto16 = cv2.multiply(producto8,producto8)
imshow(producto16)

# %% [markdown]
# en producto se llega a saturación y se puerde información

# %%
hist = cv2.calcHist([suma40], [0], None, [256], [0, 256])
plt.plot(hist, color='gray' )

plt.xlabel('intensidad de iluminacion')
plt.ylabel('cantidad de pixeles')
plt.show()

# %%
hist = cv2.calcHist([producto16], [0], None, [256], [0, 256])
plt.plot(hist, color='gray' )

plt.xlabel('intensidad de iluminacion')
plt.ylabel('cantidad de pixeles')
plt.show()

# %%
img = cv2.imread("imagenes/1004.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
suma = cv2.add(img,img)
suma2 = cv2.add(img,suma)
suma3 = cv2.add(img,suma2)
suma4 = cv2.add(img,suma3)
suma5 = cv2.add(img,suma4)
suma10= cv2.add(suma5,suma5)
suma20= cv2.add(suma10,suma10)
suma40= cv2.add(suma20,suma20)

# %%
suma = cv2.cvtColor(suma40, cv2.COLOR_BGR2RGB)
plt.imshow(suma)

# %% [markdown]
# https://facundoq.github.io/courses/aa2018/res/04_imagenes_numpy.html

# %%
negativo = 255 - suma40
imshow(suma40)

# %%
suma = cv2.add(gray,gray)
suma2 = cv2.add(gray,suma)
suma3 = cv2.add(gray,suma2)
suma4 = cv2.add(gray,suma3)
suma5 = cv2.add(gray,suma4)
suma10= cv2.add(suma5,suma5)
suma20= cv2.add(suma10,suma10)
suma40= cv2.add(suma20,suma20)
negativo = 255 - suma40
imshow(suma40)
imshow(negativo)

# %% [markdown]
# https://imaginaformacion.com/tutoriales/opencv-en-python
# https://www.geeksforgeeks.org/log-transformation-of-an-image-using-python-and-opencv/

# %% [markdown]
# # Referencias
#
# https://setosa.io/ev/image-kernels/
# https://adeveloperdiary.com/data-science/computer-vision/how-to-implement-sobel-edge-detection-using-python-from-scratch/
# https://pyimagesearch.com/2021/05/12/image-gradients-with-opencv-sobel-and-scharr/
# https://pyimagesearch.com/
#
#
#
# https://www.metabunk.org/threads/why-people-are-suddenly-seeing-strange-beams-of-light-around-the-world-the-reddit-effect.6722/
# https://en.wikipedia.org/wiki/Charge-coupled_device
# https://photo.stackexchange.com/questions/52969/why-is-there-a-vertical-bar-of-brighter-exposure-when-photographing-lightning
# https://www.kite.com/python/answers/how-to-remove-outliers-from-a-numpy-array-in-python

# %%
c = 255 / np.log(1 + np.max(img)) 
log_image = c * (np.log(img + 1)) 
log_image = np.array(log_image, dtype = np.uint8) 
   
# Display both images 
plt.imshow(img) 
plt.show() 
plt.imshow(log_image) 
plt.show()
# Out:
# C:\Users\dnsanche\AppData\Local\Temp\ipykernel_4980\1199964238.py:2: RuntimeWarning: divide by zero encountered in log
#   log_image = c * (np.log(img + 1))
# C:\Users\dnsanche\AppData\Local\Temp\ipykernel_4980\1199964238.py:3: RuntimeWarning: invalid value encountered in cast
#   log_image = np.array(log_image, dtype = np.uint8)

# %%
c = 255 / np.log(1 + np.max(negativo)) 
log_image = c * (np.log(negativo + 1)) 
log_image = np.array(log_image, dtype = np.uint8) 
   
# Display both images 
plt.imshow(negativo) 
plt.show() 
plt.imshow(log_image) 
plt.show()
# Out:
# C:\Users\dnsanche\AppData\Local\Temp\ipykernel_4980\3397561115.py:2: RuntimeWarning: divide by zero encountered in log
#   log_image = c * (np.log(negativo + 1))
# C:\Users\dnsanche\AppData\Local\Temp\ipykernel_4980\3397561115.py:3: RuntimeWarning: invalid value encountered in cast
#   log_image = np.array(log_image, dtype = np.uint8)

# %%
nueva_imagen=20*img
# Display both images 
plt.imshow(img) 
plt.show() 
plt.imshow(nueva_imagen) 
plt.show()

# %%
np.mean(gray)
# Out:
# 2.235417952674897

# %%
np.mean(negativo)
# Out:
# 220.9994174382716

# %%
sumamedia = gray - np.mean(gray)
# Display both images 
plt.imshow(gray) 
plt.show() 
plt.imshow(sumamedia) 
plt.show()
